# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_seq_items = 200
from IPython.display import display

# %%
ufc_official = pd.read_csv('ufc_official2.csv')

# %%
ufc_official.shape
# Out:
# (4291, 71)

# %%
#I will list 5 of the most important plots that I have created so far
#let's check the proportion of winners - Red fighters or Blue fighers
sns.countplot('Winner', data = ufc_official)
#at the very least we an see that Red fighters win more often
#i need to switch the colors of these boxes!!

# %%
g = sns.FacetGrid(ufc_official, row="Winner", margin_titles=True)
bins = np.linspace(start = -40, stop = 40, num = 25)
g.map(plt.hist, "reach_dif", color="steelblue", bins=bins)

# %%
sns.distplot(ufc_official['total_round_dif'], color = "blue")
sns.set(rc={'figure.figsize':(5,5)})

# %%
j = sns.FacetGrid(ufc_official, row="Winner", margin_titles=True)
bins = np.linspace(start = -40, stop = 40, num = 25)
j.map(plt.hist, "sig_str_dif", color="steelblue", bins=bins)

# %%
sns.distplot(ufc_official['reach_dif'], color = "blue")

# %%
#now for a little random forest modeling
